# %%
# %load_ext autoreload
# %autoreload 2
import dbcgen
import pandas as pd
filein='input/test_example.dbc.xlsx'
# Out:
# ldf is not supported

# %%
# read signals sheet
df=pd.read_excel(filein, sheet_name='signals')
df.head()
# Out:
#         interface                     signal     type  min      max  Unit  \
# 0  test_interface           AcCmdOvrd_IsOvrd  Boolean  NaN      NaN   NaN
# 1  test_interface   AcCmdOvrd_AcSpeedCmdOvrd  INTEGER  0.0  65535.0   NaN
# 2  test_interface  AcCmdOvrd_AcCmdEnableOvrd  Boolean  NaN      NaN   NaN
# 3  test_interface      PumpSpdOvrd_IsCmdOvrd  Boolean  NaN      NaN   NaN
# 4  test_interface        PumpSpdOvrd_cmd_prc    FLOAT  0.0    100.0   NaN
#
#    Description
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df_type=pd.read_excel(filein, sheet_name='types')
df_type.head(10)
# Out:
#       type.name        prop.name  prop.type.name prop.type.kind.name  \
# 0   AcCmdOvrd_t           IsOvrd         Boolean                  []
# 1   AcCmdOvrd_t   AcSpeedCmdOvrd  AC_Speed_rpm_t             INTEGER
# 2   AcCmdOvrd_t  AcCmdEnableOvrd         Boolean                  []
# 3  CmdPrcOvrd_t        IsCmdOvrd         Boolean                  []
# 4  CmdPrcOvrd_t          cmd_prc     value_prc_t               FLOAT
# 5        myEnum              NaN            enum                 NaN
#
#   prop.type.min_value.value prop.type.max_value.value  \
# 0                        []                        []
# 1                         0                     65535
# 2                        []                        []
# 3                        []                        []
# 4                         0                       100
# 5                       NaN                       NaN
#
#                                                 enum
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  {3: 'Not available', 2: 'Error', 1: 'Stable', ...

# %%
# prepare data for dbcgen
df_dbc = dbcgen.generate_dbc_data(df)
# Add to Excel file
df_dbc.head()
# Out:
#        Message_Name  Message_ID                Signal_Name  Start_Bit  \
# 0  test_interface_0           0           AcCmdOvrd_IsOvrd          0
# 1  test_interface_0           0   AcCmdOvrd_AcSpeedCmdOvrd          1
# 2  test_interface_0           0  AcCmdOvrd_AcCmdEnableOvrd          9
# 3  test_interface_0           0      PumpSpdOvrd_IsCmdOvrd         10
# 4  test_interface_0           0        PumpSpdOvrd_cmd_prc         11
#
#    Bit_Length  Byte_Order  Value_Type  Factor  Offset  Min      Max  Unit  \
# 0           1           0           0     1.0       0    0      1.0   NaN
# 1           8           0           0     1.0       0    0  65535.0   NaN
# 2           1           0           0     1.0       0    0      1.0   NaN
# 3           1           0           0     1.0       0    0      1.0   NaN
# 4           8           0           0     0.1       0    0    100.0   NaN
#
#   Receiver Sender
# 0      ECU    ECU
# 1      ECU    ECU
# 2      ECU    ECU
# 3      ECU    ECU
# 4      ECU    ECU

# %%
with pd.ExcelWriter(filein, engine='openpyxl', mode='a',if_sheet_exists='replace') as writer:
    df_dbc.to_excel(writer, sheet_name="DBC_Export", index=False)

print(f"Added DBC export to {filein} in sheet DBC_Export")
# Out:
# Added DBC export to input/test_example.dbc.xlsx in sheet DBC_Export

# %%
# generate dbc file content
dbcgen.generate_dbc_from_df(df_dbc, output_dbc_file="output/output.dbc")
# Out:
# DBC file created: output/output.dbc
